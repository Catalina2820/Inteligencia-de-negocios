# %% [markdown]
# # **Este es nuestro primer código de python**

# %%
#Este es nuetro primer comentario en código python.
print('Bienvenidos a la clase de inteligencia de negocios')
# Out:
# Bienvenidos a la clase de inteligencia de negocios

# %%
#Asignacion de variables
x=10
y=2.3
z='Julian'

# %%
#Preguntar por el tipo de variable
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
#Cómo realizar el casting de variables (Importante cuando tengamos una base de datos con tipos de dato trocados)
x=str(10)
y=int('1000')
z=float(2)

# %%
x=int(x)

# %%
#Asignación de múltiples variables
a, b, c = 'Julian', 30, 18.6

# %%
d = e = f = 'Inteligencia'

# %%
#Empaquetar variables (Lista)
elementos=['Lapicero','Cuaderno', 'Ganas']

# %%
g, h, i= elementos

# %%
esp=' '

# %%
print(g+esp+h+esp+i)
# Out:
# Lapicero Cuaderno Ganas

# %%
print(g,h)
# Out:
# Lapicero Cuaderno

# %%
a='Inteligencia de Negocios'
b='Metodologia de la Investigación'

# %%
#Creacion de una funcion
def saludo():
  print('Bienvenidos al curso de: '+ b)

# %%
saludo()
# Out:
# Bienvenidos al curso de: Metodologia de la Investigación

# %%
a="Nuestra cadena"                 #Cadena de caracteres
b=20                               #Enteros
c=34.2                             #Float
d=True                             #Booleano
e=3j+3                             #Complejos
f=['Elemento1','Elemento2']        #Lista
g=('Elemento1','Elemento2')        #Tupla
h=range(5)                         #Rango
i={'Elemento1':10, 'Elemento2':33} #Diccionario

# %%
#Identación 

a=10
b=14

if a > b:
  print('a es mayor que b')
else:
  print('b es mayor que a')
# Out:
# b es mayor que a

# %%
def suma():
  a=5
  b=6
  if a > b:
    print('a es mayor que b')
  else:
    print('b es mayor que a')
  return a+b

# %%
suma()
# Out:
# b es mayor que a
# 11

# %%
#Tipos de dato lista
lista=['Elemento1','Elemento2','Elemento3']

# %%
#Longitud de una lista
len(lista)
# Out:
# 3

# %%
#Acceder a un elemento específico de la lista
lista[2]
# Out:
# 'Elemento3'

# %%
lista2=['Julian', 3, 24.5, True, False, 'David']

# %%
len(lista2)
# Out:
# 6

# %%
lista2[5]
# Out:
# 'David'

# %%
if 'Julian' in lista2:
  print('El verdadero se encuentra en la lista.')
else: 
  print('El verdadero no se encuentra en la lista')
# Out:
# El verdadero se encuentra en la lista.

# %%
if 'i' in 'Julian':
  print('Se encuentra la letra i')
# Out:
# Se encuentra la letra i

# %%
lista2
# Out:
# ['Julian', 3, 24.5, True, False, 'David']

# %%
lista2[0]='Camilo'

# %%
lista2
# Out:
# ['Camilo', 3, 24.5, True, False, 'David']

# %%
tupla1=('Julian','David', 4, 10)

# %%
tupla1
# Out:
# ('Julian', 'David', 4, 10)

# %%
tupla1[0]
# Out:
# 'Julian'

# %%
dic= {'Elemento1':10, 'Elemento2':33}

# %%
dic['Elemento1']
# Out:
# 10

# %%
dic2= {'Elemento1':[a,b,c,d], 'Elemento2':[3,4,5]}

# %%
len(dic2)
# Out:
# 2

# %%
dic2['Elemento1'][1]=1000

# %%
dic2['Elemento1']
# Out:
# [10, 1000, 34.2, True]

# %%
dic2['Elemento1'][2]=[1,2,3,4,5]

# %%
dic2['Elemento1']
# Out:
# [10, 1000, [1, 2, 3, 4, 5], True]

# %%
#Ciclo for

for i in lista2:
  print(i)
# Out:
# Camilo
# 3
# 24.5
# True
# False
# David

# %%
for i in range(0,len(lista2)):
  if lista2[i]==3:
    lista2[i]=99
  else:continue

# %%
lista2
# Out:
# ['Camilo', 99, 24.5, True, False, 'David']
