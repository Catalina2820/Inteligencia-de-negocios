# %%
·@#Creación de listas
lista=[1, 2,3,4,5,2,3,0,9]

# %%
for i in range(0,len(lista)):
  if lista[i]==0:
    lista[i]=10
  else: continue

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 2, 3, 10, 9]

# %%
#Revisar el tipo de dato
type(lista)
# Out:
# list

# %%
tupla=(1,3,2,1,2,4)

# %%
lista_tupla=[]

# %%
lista2=[]

# %%
#Sirve para añadir elementos en la lista de modo siguiente
lista2.append(-1)

# %%
lista2
# Out:
# [-1]

# %%
lista2.append(20)

# %%
lista2
# Out:
# [-1, 20]

# %%
for i in range(0,len(tupla)):
  lista_tupla.append(tupla[i])

# %%
lista_tupla
# Out:
# [1, 3, 2, 1, 2, 4]

# %%
lista[5]
# Out:
# 2

# %%
lista
# Out:
# [1, 2, 3, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
#Acceder a varios elementos de la lista
lista[3:7]
# Out:
# [4, 5, 2, 3]

# %%
#Trae el ultimo elemento de la lista
lista[-1]
# Out:
# -8

# %%
lista[1:3]=[0,0,0,0,0]

# %%
lista
# Out:
# [1, 0, 0, 0, 0, 0, 0, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
#Insertar elementos a la lista
lista.insert(3,18)

# %%
lista
# Out:
# [1, 0, 0, 18, 0, 0, 0, 0, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
lista.insert(8,22)

# %%
lista
# Out:
# [1, 0, 0, 18, 0, 0, 0, 0, 22, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
lista1=[0,1,0,1]
lista2=[8,4,6,7]

# %%
#La funcion extend no trabaja añadiendo variables nuevas
lista3=lista1.extend(lista2)

# %%
lista1.extend(lista2)

# %%
lista
# Out:
# [0, 0, 18, 0, 0, 0, 0, 22, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
#Remoción de elementos especificicos de una lista
lista.remove(0)

# %%
lista
# Out:
# [18, 0, 0, 0, 22, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
#Remoción por posicion final
lista.pop()
# Out:
# -8

# %%
lista
# Out:
# [18, 0, 0, 0, 22, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99]

# %%
#Remoción por posicion especifica
lista.pop(2)
# Out:
# 22

# %%
lista
# Out:
# [18, 0, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99]

# %%
#Limpiar una lista
lista.clear()

# %%
lista
# Out:
# []

# %%
lista=[0, 0, 18, 0, 0, 0, 0, 22, 4, 5, 2, 3, 10, 9, 5, 0, 0, 99, -8]

# %%
lista=[]

# %%
lista
# Out:
# []

# %%
lista
# Out:
# [99, 22, 18, 10, 9, 5, 5, 4, 3, 2, 0, 0, -8]

# %%
for i in range(0,len(lista)):
  if(lista[i]==0):
    lista.pop(i)
  else:continue
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-73-f49169de31cb> in <module>
#       1 for i in range(0,len(lista)):
# ----> 2   if(lista[i]==0):
#       3     lista.pop(i)
#       4   else:continue
#
# IndexError: list index out of range

# %%
#Ordenamiento ascendente
lista.sort(reverse=False)

# %%
lista
# Out:
# [-8, 0, 0, 2, 3, 4, 5, 5, 9, 10, 18, 22, 99]

# %%
#Ordenamiento descendente
lista.sort(reverse=True)

# %%
lista
# Out:
# [99, 22, 18, 10, 9, 5, 5, 4, 3, 2, 0, 0, -8]

# %%
#Lista en reverso
lista.reverse()

# %%
lista
# Out:
# [-8, 99, 0, 0, 5, 9, 10, 3, 2, 5, 4, 22, 0, 0, 0, 0, 18, 0, 0]

# %%
lista3=[]

# %%
for i in range(0,len(lista)):
  lista3.append(lista[i])

# %%
lista3
# Out:
# [-8, 99, 0, 0, 5, 9, 10, 3, 2, 5, 4, 22, 0, 0, 0, 0, 18, 0, 0]

# %%
#Copia de una lista
lista_copia=lista.copy()

# %%
lista_copia
# Out:
# [-8, 99, 0, 0, 5, 9, 10, 3, 2, 5, 4, 22, 0, 0, 0, 0, 18, 0, 0]

# %%
lista
# Out:
# [-8, 99, 0, 0, 5, 9, 10, 3, 2, 5, 4, 22, 0, 0, 0, 0, 18, 0, 0]

# %%
filtrado=filter(lambda pun: pun>0,lista)

# %%
type(filtrado)
# Out:
# filter

# %%
lista_filtrada=list(filtrado)

# %%
type(list(filtrado))
# Out:
# list

# %%
#Realizar un código que permita eliminar lis elementos mayores a 5 de una lista y los asigno a una lista nueva.

# %%
lista
# Out:
# [-8, 99, 0, 0, 5, 9, 10, 3, 2, 5, 4, 22, 0, 0, 0, 0, 18, 0, 0]

# %%
#Invocación de librerias
import pandas as pd
import numpy as np

# %%
#Vector
arr=np.array([1,2,3,4,3,2])

# %%
arr
# Out:
# array([1, 2, 3, 4, 3, 2])

# %%
type(arr[0])
# Out:
# numpy.int64

# %%
#Matriz con numpy
mat=np.array([[1,2,3],[4,5,6],[0,1,0]])

# %%
mat[0][0]
# Out:
# 1

# %%
mat.ndim
# Out:
# 2

# %%
arr.ndim
# Out:
# 1

# %%
arr[0].ndim
# Out:
# 0

# %%
#Creacion de nuestra primera base de datos
data=pd.DataFrame(np.random.randint(0,100,size=(100,4)),columns=list('ABCD'))

# %%
data
# Out:
#      A   B   C   D
# 0   79  66  51  63
# 1   63  75  91  26
# 2   83   3  62  10
# 3   14  68  53  91
# 4   25  53   6  38
# ..  ..  ..  ..  ..
# 95  35  57  68  45
# 96  57  59  38   2
# 97  34  39  81  81
# 98  99  65  12  56
# 99  48  15   1  67
#
# [100 rows x 4 columns]

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data[['A','B']]
# Out:
#      A   B
# 0   79  66
# 1   63  75
# 2   83   3
# 3   14  68
# 4   25  53
# ..  ..  ..
# 95  35  57
# 96  57  59
# 97  34  39
# 98  99  65
# 99  48  15
#
# [100 rows x 2 columns]

# %%
type(data['A'])
# Out:
# pandas.core.series.Series

# %%
data['B'][1]
# Out:
# 75

# %%
data['B'][1]=0

# %%
data
# Out:
#      A   B   C   D
# 0   79  66  51  63
# 1   63   0  91  26
# 2   83   3  62  10
# 3   14  68  53  91
# 4   25  53   6  38
# ..  ..  ..  ..  ..
# 95  35  57  68  45
# 96  57  59  38   2
# 97  34  39  81  81
# 98  99  65  12  56
# 99  48  15   1  67
#
# [100 rows x 4 columns]

# %%
#De la base de datos creada, cambie los elementos de la columna b y d que estan por debajo de 10, cambie por un 0
