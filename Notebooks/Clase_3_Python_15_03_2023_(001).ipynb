# %%
import pandas as pd

# %%
#Poner una lista en un DataFrame
lista=['Matematicas', 'Lengua', 'Sociales','Ingles','Ed. Fisica']

# %%
data=pd.DataFrame(lista)

# %%
data
# Out:
#              0
# 0  Matematicas
# 1       Lengua
# 2     Sociales
# 3       Ingles
# 4   Ed. Fisica

# %%
#Comando para revisar las columnas
data.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
df=pd.DataFrame(lista, index=['a','b','c','d','e'],columns=['Asignaturas'])

# %%
df
# Out:
#    Asignaturas
# a  Matematicas
# b       Lengua
# c     Sociales
# d       Ingles
# e   Ed. Fisica

# %%
df.columns
# Out:
# Index(['Asignaturas'], dtype='object')

# %%
df=pd.DataFrame(lista,columns=['Asignaturas'])

# %%
df
# Out:
#    Asignaturas
# 0  Matematicas
# 1       Lengua
# 2     Sociales
# 3       Ingles
# 4   Ed. Fisica

# %%
lista2=[4.3, 4,3.1,2.7,5]

# %%
data=pd.DataFrame(list(zip(lista,lista2)),columns=['Asignatura','Nota'])

# %%
data
# Out:
#     Asignatura  Nota
# 0  Matematicas   4.3
# 1       Lengua   4.0
# 2     Sociales   3.1
# 3       Ingles   2.7
# 4   Ed. Fisica   5.0

# %%
a=list(zip(lista,lista2))

# %%
a
# Out:
# [('Matematicas', 4.3),
#  ('Lengua', 4),
#  ('Sociales', 3.1),
#  ('Ingles', 2.7),
#  ('Ed. Fisica', 5)]

# %%
#Generacion de base de datos a partir de un diccionario
Nombres=['Julian','Camila','Carlos', 'Alejandra']
Apellidos=['Rojo','Restrepo','Duica','Correa']
Puntajes=[68,74,87,81]

# %%
relacion= {
              'Nombre': Nombres,
              'Apellido': Apellidos,
              'Puntaje': Puntajes
          }

# %%
relacion
# Out:
# {'Nombre': ['Julian', 'Camila', 'Carlos', 'Alejandra'],
#  'Apellido': ['Rojo', 'Restrepo', 'Duica', 'Correa'],
#  'Puntaje': [68, 74, 87, 81]}

# %%
relacion['Apellido']
# Out:
# ['Rojo', 'Restrepo', 'Duica', 'Correa']

# %%
#Construye el DataFrame
data=pd.DataFrame(relacion)

# %%
data
# Out:
#       Nombre  Apellido  Puntaje
# 0     Julian      Rojo       68
# 1     Camila  Restrepo       74
# 2     Carlos     Duica       87
# 3  Alejandra    Correa       81

# %%
data['Puntaje'].mean()
# Out:
# 77.5

# %%
#Realizar cargas de datos (Debemos garantizar que estamos usando la libreria pandas)
data=pd.read_json('https://www.datos.gov.co/resource/7vr4-y6we.json')

# %%
data
# Out:
#            serie_documental_s             nombre_o_t_tulo_de_la_categor  \
# 0   ACCIONES CONSTITUCIONALES                        ACCIONES POPULARES
# 1   ACCIONES CONSTITUCIONALES                        ACCIONES DE TUTELA
# 2                       ACTAS                  ACTAS DE JUNTA DIRECTIVA
# 3                       ACTAS               ACTAS DE COMITÉ DE GERENCIA
# 4                       ACTAS               ACTAS DE REUNIONES INTERNAS
# ..                        ...                                       ...
# 80                   INFORMES  INFORMES CONTADURÍA GENERAL DE LA NACIÓN
# 81           LIBROS CONTABLES                         LIBROS AUXILIARES
# 82           LIBROS CONTABLES                 LIBRO MAYOR Y DE BALANCES
# 83               COMPROBANTES                   COMPROBANTES DE EGRESOS
# 84               COMPROBANTES                   COMPROBANTES DE INGRESO
#
#    clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['serie_documental_s', 'nombre_o_t_tulo_de_la_categor',
#        'clasificaci_n_del_activo', 'fecha_de_generaci_n_de_la',
#        'nombre_del_responsable_de', 'nombre_del_responsable_de_1',
#        'objetivo_leg_timo_de_la', 'fundamento_constitucional',
#        'fundamento_jur_dico_de_la', 'excepci_n_total_o_parcial',
#        'plazo_de_clasificaci_n_o'],
#       dtype='object')

# %%
data.columns[5]
# Out:
# 'nombre_del_responsable_de_1'

# %%
data['nombre_del_responsable_de_1']
# Out:
# 0     GESTION DOCUMENTAL
# 1     GESTION DOCUMENTAL
# 2     GESTION DOCUMENTAL
# 3     GESTION DOCUMENTAL
# 4     GESTION DOCUMENTAL
#              ...
# 80    GESTION DOCUMENTAL
# 81    GESTION DOCUMENTAL
# 82    GESTION DOCUMENTAL
# 83    GESTION DOCUMENTAL
# 84    GESTION DOCUMENTAL
# Name: nombre_del_responsable_de_1, Length: 85, dtype: object

# %%
data[data.columns[5]]
# Out:
# 0     GESTION DOCUMENTAL
# 1     GESTION DOCUMENTAL
# 2     GESTION DOCUMENTAL
# 3     GESTION DOCUMENTAL
# 4     GESTION DOCUMENTAL
#              ...
# 80    GESTION DOCUMENTAL
# 81    GESTION DOCUMENTAL
# 82    GESTION DOCUMENTAL
# 83    GESTION DOCUMENTAL
# 84    GESTION DOCUMENTAL
# Name: nombre_del_responsable_de_1, Length: 85, dtype: object

# %%
#Los n primeros datos
data.head()
# Out:
#           serie_documental_s nombre_o_t_tulo_de_la_categor  \
# 0  ACCIONES CONSTITUCIONALES            ACCIONES POPULARES
# 1  ACCIONES CONSTITUCIONALES            ACCIONES DE TUTELA
# 2                      ACTAS      ACTAS DE JUNTA DIRECTIVA
# 3                      ACTAS   ACTAS DE COMITÉ DE GERENCIA
# 4                      ACTAS   ACTAS DE REUNIONES INTERNAS
#
#   clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# 0                RESERVADA                PERMANENTE
# 1                RESERVADA                PERMANENTE
# 2              CLASIFICADA                PERMANENTE
# 3              CLASIFICADA                PERMANENTE
# 4              CLASIFICADA                PERMANENTE
#
#   nombre_del_responsable_de nombre_del_responsable_de_1  \
# 0          GERENCIA GENERAL          GESTION DOCUMENTAL
# 1          GERENCIA GENERAL          GESTION DOCUMENTAL
# 2          GERENCIA GENERAL          GESTION DOCUMENTAL
# 3          GERENCIA GENERAL          GESTION DOCUMENTAL
# ...

# %%
#Los n ultimos datos
data.tail(4)
# Out:
#    serie_documental_s nombre_o_t_tulo_de_la_categor clasificaci_n_del_activo  \
# 81   LIBROS CONTABLES             LIBROS AUXILIARES              CLASIFICADA
# 82   LIBROS CONTABLES     LIBRO MAYOR Y DE BALANCES              CLASIFICADA
# 83       COMPROBANTES       COMPROBANTES DE EGRESOS              CLASIFICADA
# 84       COMPROBANTES       COMPROBANTES DE INGRESO              CLASIFICADA
#
#    fecha_de_generaci_n_de_la        nombre_del_responsable_de  \
# 81                PERMANENTE  OFICINA CONTABLE Y PRESUPUESTAL
# 82                PERMANENTE  OFICINA CONTABLE Y PRESUPUESTAL
# 83                PERMANENTE                        TESORERÍA
# 84                PERMANENTE                        TESORERÍA
#
#    nombre_del_responsable_de_1  \
# 81          GESTION DOCUMENTAL
# 82          GESTION DOCUMENTAL
# 83          GESTION DOCUMENTAL
# 84          GESTION DOCUMENTAL
#
#                               objetivo_leg_timo_de_la  \
# ...

# %%
data.tail(83)
# Out:
#    serie_documental_s             nombre_o_t_tulo_de_la_categor  \
# 2               ACTAS                  ACTAS DE JUNTA DIRECTIVA
# 3               ACTAS               ACTAS DE COMITÉ DE GERENCIA
# 4               ACTAS               ACTAS DE REUNIONES INTERNAS
# 5               ACTAS               ACTAS DE REUNIONES EXTERNAS
# 6            ACUERDOS               ACUERDOS DE JUNTA DIRECTIVA
# ..                ...                                       ...
# 80           INFORMES  INFORMES CONTADURÍA GENERAL DE LA NACIÓN
# 81   LIBROS CONTABLES                         LIBROS AUXILIARES
# 82   LIBROS CONTABLES                 LIBRO MAYOR Y DE BALANCES
# 83       COMPROBANTES                   COMPROBANTES DE EGRESOS
# 84       COMPROBANTES                   COMPROBANTES DE INGRESO
#
#    clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# 2               CLASIFICADA                PERMANENTE
# 3               CLASIFICADA                PERMANENTE
# ...

# %%
data.head(2)
# Out:
#           serie_documental_s nombre_o_t_tulo_de_la_categor  \
# 0  ACCIONES CONSTITUCIONALES            ACCIONES POPULARES
# 1  ACCIONES CONSTITUCIONALES            ACCIONES DE TUTELA
#
#   clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# 0                RESERVADA                PERMANENTE
# 1                RESERVADA                PERMANENTE
#
#   nombre_del_responsable_de nombre_del_responsable_de_1  \
# 0          GERENCIA GENERAL          GESTION DOCUMENTAL
# 1          GERENCIA GENERAL          GESTION DOCUMENTAL
#
#                              objetivo_leg_timo_de_la  \
# 0  Derecho a la Intimidad, Derecho a al Vida, der...
# 1  Derecho a la Intimidad, Derecho a al Vida, der...
#
#                            fundamento_constitucional  \
# 0  Art. 3, 5, 6 y 7 de la Ley 1581 de 2012).  En ...
# 1  Art. 3, 5, 6 y 7 de la Ley 1581 de 2012).  En ...
#
#                            fundamento_jur_dico_de_la  \
# 0  Ley 906 de 2004 art. 18, 212B, 345, 125, 149, ...
# ...

# %%
data.iloc[[0,1,5,8]]
# Out:
#           serie_documental_s nombre_o_t_tulo_de_la_categor  \
# 0  ACCIONES CONSTITUCIONALES            ACCIONES POPULARES
# 1  ACCIONES CONSTITUCIONALES            ACCIONES DE TUTELA
# 5                      ACTAS   ACTAS DE REUNIONES EXTERNAS
# 8                  CONTRATOS    CONTRATOS DE ARRENDAMIENTO
#
#   clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# 0                RESERVADA                PERMANENTE
# 1                RESERVADA                PERMANENTE
# 5              CLASIFICADA                PERMANENTE
# 8              CLASIFICADA                PERMANENTE
#
#   nombre_del_responsable_de nombre_del_responsable_de_1  \
# 0          GERENCIA GENERAL          GESTION DOCUMENTAL
# 1          GERENCIA GENERAL          GESTION DOCUMENTAL
# 5    TODAS LAS DEPENDENCIAS          GESTION DOCUMENTAL
# 8          GERENCIA GENERAL          GESTION DOCUMENTAL
#
#                              objetivo_leg_timo_de_la  \
# 0  Derecho a la Intimidad, Derecho a al Vida, der...
# ...

# %%
data.iloc[3:7]
# Out:
#   serie_documental_s nombre_o_t_tulo_de_la_categor clasificaci_n_del_activo  \
# 3              ACTAS   ACTAS DE COMITÉ DE GERENCIA              CLASIFICADA
# 4              ACTAS   ACTAS DE REUNIONES INTERNAS              CLASIFICADA
# 5              ACTAS   ACTAS DE REUNIONES EXTERNAS              CLASIFICADA
# 6           ACUERDOS   ACUERDOS DE JUNTA DIRECTIVA              CLASIFICADA
#
#   fecha_de_generaci_n_de_la nombre_del_responsable_de  \
# 3                PERMANENTE          GERENCIA GENERAL
# 4                PERMANENTE    TODAS LAS DEPENDENCIAS
# 5                PERMANENTE    TODAS LAS DEPENDENCIAS
# 6                PERMANENTE          GERENCIA GENERAL
#
#   nombre_del_responsable_de_1  \
# 3          GESTION DOCUMENTAL
# 4          GESTION DOCUMENTAL
# 5          GESTION DOCUMENTAL
# 6          GESTION DOCUMENTAL
#
#                              objetivo_leg_timo_de_la  \
# 3  Tiene reserva legal, además de contener secret...
# ...

# %%
data[data.columns[2]].value_counts(dropna=False)
# Out:
# CLASIFICADA    71
# RESERVADA      14
# Name: clasificaci_n_del_activo, dtype: int64

# %%
for i in range(0,len(data)):
  if(data[data.columns[2]][i]=='RESERVADA'):
    data[data.columns[2]][i]='Cosa1'
  else:
    data[data.columns[2]][i]='Cosa2'

# %%
data
# Out:
#            serie_documental_s             nombre_o_t_tulo_de_la_categor  \
# 0   ACCIONES CONSTITUCIONALES                        ACCIONES POPULARES
# 1   ACCIONES CONSTITUCIONALES                        ACCIONES DE TUTELA
# 2                       ACTAS                  ACTAS DE JUNTA DIRECTIVA
# 3                       ACTAS               ACTAS DE COMITÉ DE GERENCIA
# 4                       ACTAS               ACTAS DE REUNIONES INTERNAS
# ..                        ...                                       ...
# 80                   INFORMES  INFORMES CONTADURÍA GENERAL DE LA NACIÓN
# 81           LIBROS CONTABLES                         LIBROS AUXILIARES
# 82           LIBROS CONTABLES                 LIBRO MAYOR Y DE BALANCES
# 83               COMPROBANTES                   COMPROBANTES DE EGRESOS
# 84               COMPROBANTES                   COMPROBANTES DE INGRESO
#
#    clasificaci_n_del_activo fecha_de_generaci_n_de_la  \
# ...

# %%
#Cargar datos con google colab
import pandas as pd
import numpy as np
import io
from google.colab import files

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-5f558eb4-bc3c-4f5a-8b56-9c5af0ec7dc7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f558eb4-bc3c-4f5a-8b56-9c5af0ec7dc7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(io.BytesIO(uploaded['cambridge001.csv']))

# %%
data.head()
# Out:
#   File Number          Date of Report           Crime Date Time  \
# 0  2009-00002  01/01/2009 12:39:00 AM               1/1/09 0:39
# 1  2009-00003  01/01/2009 01:34:00 AM               1/1/09 1:34
# 2  2009-00004  01/01/2009 01:43:00 AM  01/01/2009 02:20 - 02:35
# 3  2009-00005  01/01/2009 02:27:00 AM  01/01/2009 02:20 - 02:45
# 4  2009-00006  01/01/2009 02:34:00 AM  01/01/2009 02:15 - 02:35
#
#                 Crime  Reporting Area    Neighborhood  \
# 0      Simple Assault           504.0   Cambridgeport
# 1      Simple Assault           610.0   Mid-Cambridge
# 2  Aggravated Assault           708.0       Riverside
# 3      Simple Assault           105.0  East Cambridge
# 4          Disorderly           708.0       Riverside
#
#                                             Location
# 0            400 Massachusetts Avenue, Cambridge, MA
# 1                200 HAMPSHIRE STREET, Cambridge, MA
# 2  DUNSTER STREET & MOUNT AUBURN STREET, Cambridg...
# ...

# %%
data.columns
# Out:
# Index(['File Number', 'Date of Report', 'Crime Date Time', 'Crime',
#        'Reporting Area', 'Neighborhood', 'Location'],
#       dtype='object')

# %%
#Cómo borrar columnas
data=data.drop('Location',axis=1)

# %%
data=data.drop(data.columns[2],axis=1)

# %%
data
# Out:
#       File Number          Date of Report                   Crime  \
# 0      2009-00002  01/01/2009 12:39:00 AM          Simple Assault
# 1      2009-00003  01/01/2009 01:34:00 AM          Simple Assault
# 2      2009-00004  01/01/2009 01:43:00 AM      Aggravated Assault
# 3      2009-00005  01/01/2009 02:27:00 AM          Simple Assault
# 4      2009-00006  01/01/2009 02:34:00 AM              Disorderly
# ...           ...                     ...                     ...
# 56009  2016-07187  09/30/2016 04:05:00 PM  Larceny from Residence
# 56010  2016-07189  09/30/2016 05:38:00 PM             Hit and Run
# 56011  2016-07192  09/30/2016 06:52:00 PM              Harassment
# 56012  2016-07194  09/30/2016 07:52:00 PM             Hit and Run
# 56013  2016-07195  09/30/2016 09:44:00 PM          Simple Assault
#
#        Reporting Area     Neighborhood
# 0               504.0    Cambridgeport
# 1               610.0    Mid-Cambridge
# 2               708.0        Riverside
# ...

# %%
data.columns[2]
# Out:
# 'Crime'

# %%
#Creacion de una nueva columna
data['Columna Nueva']='Predeterminado'

# %%
data['Reporting Area']
# Out:
# 0         504.0
# 1         610.0
# 2         708.0
# 3         105.0
# 4         708.0
#           ...
# 56009     510.0
# 56010    1105.0
# 56011     702.0
# 56012    1002.0
# 56013    1002.0
# Name: Reporting Area, Length: 56014, dtype: float64

# %%
data
# Out:
#       File Number          Date of Report                   Crime  \
# 0      2009-00002  01/01/2009 12:39:00 AM          Simple Assault
# 1      2009-00003  01/01/2009 01:34:00 AM          Simple Assault
# 2      2009-00004  01/01/2009 01:43:00 AM      Aggravated Assault
# 3      2009-00005  01/01/2009 02:27:00 AM          Simple Assault
# 4      2009-00006  01/01/2009 02:34:00 AM              Disorderly
# ...           ...                     ...                     ...
# 56009  2016-07187  09/30/2016 04:05:00 PM  Larceny from Residence
# 56010  2016-07189  09/30/2016 05:38:00 PM             Hit and Run
# 56011  2016-07192  09/30/2016 06:52:00 PM              Harassment
# 56012  2016-07194  09/30/2016 07:52:00 PM             Hit and Run
# 56013  2016-07195  09/30/2016 09:44:00 PM          Simple Assault
#
#        Reporting Area     Neighborhood   Columna Nueva
# 0               504.0    Cambridgeport  Predeterminado
# 1               610.0    Mid-Cambridge  Predeterminado
# ...

# %%
for i in range(0,len(data)):
  data['Columna Nueva'][i]=(data['Reporting Area'].mean()-data['Reporting Area'][i])/data['Reporting Area'].max()
# Out:
# <ipython-input-109-50830b70571f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Columna Nueva'][i]=(data['Reporting Area'].mean()-data['Reporting Area'][i])/data['Reporting Area'].max()

# %%
data['Reporting Area'].max()
# Out:
# 1304.0

# %%
data['Columna Nueva']=abs(data['Columna Nueva'])

# %%
data
# Out:
#       File Number          Date of Report                   Crime  \
# 0      2009-00002  01/01/2009 12:39:00 AM          Simple Assault
# 1      2009-00003  01/01/2009 01:34:00 AM          Simple Assault
# 2      2009-00004  01/01/2009 01:43:00 AM      Aggravated Assault
# 3      2009-00005  01/01/2009 02:27:00 AM          Simple Assault
# 4      2009-00006  01/01/2009 02:34:00 AM              Disorderly
# ...           ...                     ...                     ...
# 56009  2016-07187  09/30/2016 04:05:00 PM  Larceny from Residence
# 56010  2016-07189  09/30/2016 05:38:00 PM             Hit and Run
# 56011  2016-07192  09/30/2016 06:52:00 PM              Harassment
# 56012  2016-07194  09/30/2016 07:52:00 PM             Hit and Run
# 56013  2016-07195  09/30/2016 09:44:00 PM          Simple Assault
#
#        Reporting Area     Neighborhood Columna Nueva
# 0               504.0    Cambridgeport      0.088768
# 1               610.0    Mid-Cambridge       0.00748
# ...

# %%
#Tomar la data llamada 'Rajasthan_1990_2022_Jodhpur' desde el drive deben poner una de las columnas (Numerica) en una lista y luego calcular su promedio
