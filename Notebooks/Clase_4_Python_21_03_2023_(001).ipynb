# %%
import pandas as pd
import numpy as np
from google.colab import files 
import io

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-1c5063db-fa08-4d6d-bfc3-9ce81e373981" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1c5063db-fa08-4d6d-bfc3-9ce81e373981">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(io.BytesIO(uploaded['bank.csv']))

# %%
data.head()
# Out:
#                                 Bank Name         City State   CERT  \
# 0                             Allied Bank     Mulberry    AR     91
# 1                      Trust Company Bank      Memphis    TN   9956
# 2                  Hometown National Bank     Longview    WA  35156
# 3                      Northern Star Bank      Mankato    MN  34983
# 4  Frontier Bank, FSB D/B/A El Paseo Bank  Palm Desert    CA  34738
#
#                Acquiring Institution Closing Date Updated Date Acq_Inst
# 0                       Today's Bank    23-Sep-16    29-Sep-16      NaN
# 1         The Bank of Fayette County    29-Apr-16     6-Sep-16      NaN
# 2                     Twin City Bank     2-oct-15    13-Apr-16      NaN
# 3                          BankVista    19-Dec-14     6-Jan-16      NaN
# 4  Bank of Southern California, N.A.     7-nov-14     6-Jan-16      NaN

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
type(data.columns.values)
# Out:
# numpy.ndarray

# %%
data[data.columns[3]].values
# Out:
# array([   91,  9956, 35156, 34983, 34738,  4862, 28462, 12483, 21793,
#        15062, 58531, 35096, 17967, 57431, 14318, 34707, 19849, 35016,
#        34943, 34789, 34527, 58185, 26680, 29594, 58066, 16431, 57157,
#        27331, 58073, 20685, 27986, 57096,  1056,  1690, 27405, 34515,
#          416, 35224, 23156, 32503, 35527, 34046, 29761, 23187, 34823,
#        57917, 58343, 14194, 57860, 19397, 35395, 58046, 33513, 20408,
#        57212, 35356,  4392, 58283, 57442, 57835, 34234, 14273, 17750,
#        19794, 34292,  4077, 57855, 13272, 35242,  5328,  2303, 23306,
#        58052, 58495, 35561, 35078, 57885, 22173, 33904, 32251, 34016,
#        35250, 27808, 57107, 15640, 31623, 23181, 34486, 10506, 28136,
#        11636, 58072, 34152, 29341, 15814, 57735, 35586, 57697, 16476,
#        17792, 58362, 32185, 27150, 58429,  3735, 23876, 26619,  8221,
#        24957, 58104, 18806, 29561, 58352,  3287, 15448, 16133, 32498,
# ...

# %%
data.describe()
# Out:
#                CERT
# count    547.000000
# mean   31748.842779
# std    16411.363900
# min       91.000000
# 25%    20352.000000
# 50%    32218.000000
# 75%    35364.000000
# max    58701.000000

# %%
data.dtypes
# Out:
# Bank Name                object
# City                     object
# State                    object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# Acq_Inst                 object
# dtype: object

# %%
data.head()
# Out:
#                                 Bank Name         City State   CERT  \
# 0                             Allied Bank     Mulberry    AR     91
# 1                      Trust Company Bank      Memphis    TN   9956
# 2                  Hometown National Bank     Longview    WA  35156
# 3                      Northern Star Bank      Mankato    MN  34983
# 4  Frontier Bank, FSB D/B/A El Paseo Bank  Palm Desert    CA  34738
#
#                Acquiring Institution Closing Date Updated Date Acq_Inst
# 0                       Today's Bank    23-Sep-16    29-Sep-16      NaN
# 1         The Bank of Fayette County    29-Apr-16     6-Sep-16      NaN
# 2                     Twin City Bank     2-oct-15    13-Apr-16      NaN
# 3                          BankVista    19-Dec-14     6-Jan-16      NaN
# 4  Bank of Southern California, N.A.     7-nov-14     6-Jan-16      NaN

# %%
from pandas_profiling import ProfileReport

# %%
prof=ProfileReport(data)

# %%
prof
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.2.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-03-22 01:33:27.259588&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
#Borrado de columnas 
df=data.drop(data.columns[-1], axis=1)

# %%
df
# Out:
#                                   Bank Name             City State   CERT  \
# 0                               Allied Bank         Mulberry    AR     91
# 1                        Trust Company Bank          Memphis    TN   9956
# 2                    Hometown National Bank         Longview    WA  35156
# 3                        Northern Star Bank          Mankato    MN  34983
# 4    Frontier Bank, FSB D/B/A El Paseo Bank      Palm Desert    CA  34738
# ..                                      ...              ...   ...    ...
# 542                     Dollar Savings Bank           Newark    NJ  31330
# 543                           Bank of Alamo            Alamo    TN   9961
# 544              AmTrade International Bank          Atlanta    GA  33784
# 545                        New Century Bank  Shelby Township    MI  34979
# 546                            NextBank, NA          Phoenix    AZ  22314
#
#                  Acquiring Institution Closing Date Updated Date
# ...

# %%
#Renombrar o cambiar nombres de columnas
df.rename(columns={df.columns[0]:'Nombre del banco'}, inplace=True)

# %%
df
# Out:
#                            Nombre del banco             City State   CERT  \
# 0                               Allied Bank         Mulberry    AR     91
# 1                        Trust Company Bank          Memphis    TN   9956
# 2                    Hometown National Bank         Longview    WA  35156
# 3                        Northern Star Bank          Mankato    MN  34983
# 4    Frontier Bank, FSB D/B/A El Paseo Bank      Palm Desert    CA  34738
# ..                                      ...              ...   ...    ...
# 542                     Dollar Savings Bank           Newark    NJ  31330
# 543                           Bank of Alamo            Alamo    TN   9961
# 544              AmTrade International Bank          Atlanta    GA  33784
# 545                        New Century Bank  Shelby Township    MI  34979
# 546                            NextBank, NA          Phoenix    AZ  22314
#
#                  Acquiring Institution Closing Date Updated Date
# ...

# %%
#Renombrar o cambiar nombres de columnas
data.rename(columns={df.columns[0]:'Nombre del banco'}, inplace=False)
# Out:
#                                   Bank Name             City State   CERT  \
# 0                               Allied Bank         Mulberry    AR     91
# 1                        Trust Company Bank          Memphis    TN   9956
# 2                    Hometown National Bank         Longview    WA  35156
# 3                        Northern Star Bank          Mankato    MN  34983
# 4    Frontier Bank, FSB D/B/A El Paseo Bank      Palm Desert    CA  34738
# ..                                      ...              ...   ...    ...
# 542                     Dollar Savings Bank           Newark    NJ  31330
# 543                           Bank of Alamo            Alamo    TN   9961
# 544              AmTrade International Bank          Atlanta    GA  33784
# 545                        New Century Bank  Shelby Township    MI  34979
# 546                            NextBank, NA          Phoenix    AZ  22314
#
#                  Acquiring Institution Closing Date Updated Date     Acq_Inst
# ...

# %%
data
# Out:
#                                   Bank Name             City State   CERT  \
# 0                               Allied Bank         Mulberry    AR     91
# 1                        Trust Company Bank          Memphis    TN   9956
# 2                    Hometown National Bank         Longview    WA  35156
# 3                        Northern Star Bank          Mankato    MN  34983
# 4    Frontier Bank, FSB D/B/A El Paseo Bank      Palm Desert    CA  34738
# ..                                      ...              ...   ...    ...
# 542                     Dollar Savings Bank           Newark    NJ  31330
# 543                           Bank of Alamo            Alamo    TN   9961
# 544              AmTrade International Bank          Atlanta    GA  33784
# 545                        New Century Bank  Shelby Township    MI  34979
# 546                            NextBank, NA          Phoenix    AZ  22314
#
#                  Acquiring Institution Closing Date Updated Date     Acq_Inst
# ...

# %%
data[data.columns[1]].value_counts(dropna=False)
# Out:
# Chicago            18
# Atlanta            10
# Phoenix             6
# Naples              5
# Alpharetta          4
#                    ..
# Northville          1
# Eldred              1
# Sanderson           1
# Cape Coral          1
# Shelby Township     1
# Name: City, Length: 421, dtype: int64

# %%
#Barra cargadora
from tqdm import tqdm

# %%
for i in tqdm(range(0,len(data))):
  if(data[data.columns[1]][i]=='Chicago') or (data[data.columns[1]][i]=='Atlanta'):
    data[data.columns[1]][i]='No registra'
  else: continue
# Out:
#   0%|          | 0/547 [00:00<?, ?it/s]<ipython-input-32-c290aa40aa45>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[data.columns[1]][i]='No registra'
# 100%|██████████| 547/547 [00:00<00:00, 22937.57it/s]

# %%
url='https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'

# %%
data=pd.read_csv(url)

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#Casting de columnas de variables
data[data.columns[0]]=data[data.columns[0]].map(str)
data[data.columns[0]]=data[data.columns[0]].apply(str)

# %%
type(data[data.columns[0]][0])
# Out:
# str

# %%
data['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
#Exploracion de datos vacios
pd.isnull(data['Cabin']).value_counts()
# Out:
# True     687
# False    204
# Name: Cabin, dtype: int64

# %%
pd.notnull(data['Cabin']).value_counts()
# Out:
# False    687
# True     204
# Name: Cabin, dtype: int64

# %%
pd.isnull(data['Cabin']).values.ravel().sum()
# Out:
# 687

# %%
data['Calculo']=0

# %%
for i in tqdm(range(0,len(data))):
  data['Calculo'][i]=(data['Age'][i]-data['Age'].mean())/(data['Age'].max()-data['Age'].min())
# Out:
#   0%|          | 0/891 [00:00<?, ?it/s]<ipython-input-56-55a324609ab4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Calculo'][i]=(data['Age'][i]-data['Age'].mean())/(data['Age'].max()-data['Age'].min())
# 100%|██████████| 891/891 [00:00<00:00, 4503.59it/s]

# %%
data['Calculo']=abs(data['Calculo'])

# %%
data
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 886         887         0       2
# 887         888         1       1
# 888         889         0       3
# 889         890         1       1
# 890         891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
