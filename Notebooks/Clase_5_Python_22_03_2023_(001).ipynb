# %%
import pandas as pd
import numpy as np
from google.colab import files
import io
import tqdm as tqdm

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-67eab554-3aa7-4964-b82d-de4888f3fc83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67eab554-3aa7-4964-b82d-de4888f3fc83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv(io.BytesIO(uploaded['diabetes001.csv']))

# %%
data.head()
# Out:
#    Edad (años) Grupo de edad  Genero    Etnia    Zona  Discapacidad  \
# 0           68      65 y mas       2  Mestizo  Urbana           NaN
# 1           55       45 a 64       2  Mestizo  Urbana           NaN
# 2           62       45 a 64       1  Mestizo  Urbana           NaN
# 3           69      65 y mas       2  Mestizo  Urbana           NaN
# 4           62       45 a 64       2  Mestizo  Urbana           NaN
#
#   Afiliacion SGSSS  Escolaridad Regimen de Afiliación Fecha Control  ...  \
# 0         EMSSANAR            1            SUBSIDIADO    28/06/2017  ...
# 1         EMSSANAR            2          CONTRIBUTIVO    25/05/2017  ...
# 2         EMSSANAR            1            SUBSIDIADO    17/05/2017  ...
# 3         EMSSANAR            2            SUBSIDIADO    15/05/2017  ...
# 4         EMSSANAR            1            SUBSIDIADO    12/05/2017  ...
#
#   Calculo de  TFG corregida (Cockcroft-Gault)   Estadio IRC  \
# ...

# %%
len(data)
# Out:
# 1174

# %%
data.dtypes
# Out:
# Edad (años)                                                    int64
# Grupo de edad                                                 object
# Genero                                                         int64
# Etnia                                                         object
# Zona                                                          object
# Discapacidad                                                 float64
# Afiliacion SGSSS                                              object
# Escolaridad                                                    int64
# Regimen de Afiliación                                         object
# Fecha Control                                                 object
# Fumador Activo                                                object
# ¿Diabetes?                                                    object
# Hipertensión Arterial Sistemica                               object
# HTA + DM                                                      object
# ...

# %%
#Reset de indices
data=data.reset_index()

# %%
data
# Out:
#       index  Edad (años) Grupo de edad  Genero    Etnia    Zona  Discapacidad  \
# 0         0           68      65 y mas       2  Mestizo  Urbana           NaN
# 1         1           55       45 a 64       2  Mestizo  Urbana           NaN
# 2         2           62       45 a 64       1  Mestizo  Urbana           NaN
# 3         3           69      65 y mas       2  Mestizo  Urbana           NaN
# 4         4           62       45 a 64       2  Mestizo  Urbana           NaN
# ...     ...          ...           ...     ...      ...     ...           ...
# 1169   1169           62       45 a 64       2     Otra  Urbana           0.0
# 1170   1170           57       45 a 64       2     Otra  Urbana           0.0
# 1171   1171           48       45 a 64       2     Otra  Urbana           0.0
# 1172   1172           70      65 y mas       2     Otra  Urbana           0.0
# 1173   1173           69      65 y mas       1     Otra  Urbana           0.0
#
# ...

# %%
data=data.drop('index',axis=1)

# %%
data.columns
# Out:
# Index(['Edad (años)', 'Grupo de edad', 'Genero', 'Etnia', 'Zona',
#        'Discapacidad', 'Afiliacion SGSSS', 'Escolaridad',
#        'Regimen de Afiliación', 'Fecha Control', 'Fumador Activo',
#        '¿Diabetes?', 'Hipertensión Arterial Sistemica', 'HTA + DM',
#        'Clasificacion de Diabetes o del ultimo estado de Glicemia',
#        'Complicaciones  y Lesiones en Organo Blanco',
#        'Antecedentes Fliar  Enfermedad Coronaria', 'Tension SISTOLICA',
#        'Tension DIASTOLICA', 'HTA COMPENSADOS', 'Colesterol Total',
#        'Colesterol HDL', 'Trigliceridos', 'Colesterol LDL',
#        'CALCULO DE RIESGO DE Framingham (% a 10 años)',
#        'Clasificación de RCV Global', 'Hemoglobina A1C', 'DM COMPENSADO',
#        'HTA Y DM COMPENSADA', 'Glicemia de ayuno', 'Glicemia  Pos prandial',
#        'Perimetro Abdominal', 'Clasificación perímetro abdominal', 'Peso',
#        'Talla', 'IMC', 'CLAIFICACION IMC', 'Creatinina',
# ...

# %%
#Se seleccionan determinadas columnas para un subconjunto de datos
data=data[['Edad (años)','Grupo de edad', 'Genero', 'Regimen de Afiliación', 'Fecha Control','Fumador Activo','¿Diabetes?', 'Hipertensión Arterial Sistemica', 'HTA + DM',
           'Tension SISTOLICA', 'Tension DIASTOLICA', 'HTA COMPENSADOS', 'Colesterol Total','Colesterol HDL', 'Trigliceridos', 'Colesterol LDL']]

# %%
data.columns
# Out:
# Index(['Edad (años)', 'Grupo de edad', 'Genero', 'Regimen de Afiliación',
#        'Fecha Control', 'Fumador Activo', '¿Diabetes?',
#        'Hipertensión Arterial Sistemica', 'HTA + DM', 'Tension SISTOLICA',
#        'Tension DIASTOLICA', 'HTA COMPENSADOS', 'Colesterol Total',
#        'Colesterol HDL', 'Trigliceridos', 'Colesterol LDL'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Edad (años)       Genero  Tension SISTOLICA  Tension DIASTOLICA  \
# count  1174.000000  1174.000000        1174.000000         1174.000000
# mean     64.069847     1.716354         128.231687           80.950596
# std      12.712919     0.450959          15.148680            9.070113
# min      16.000000     1.000000          60.000000           30.000000
# 25%      55.000000     1.000000         120.000000           80.000000
# 50%      64.000000     2.000000         120.000000           80.000000
# 75%      73.000000     2.000000         140.000000           85.000000
# max      98.000000     2.000000         200.000000          180.000000
#
#        Colesterol Total  Colesterol HDL  Trigliceridos  Colesterol LDL
# count       1174.000000     1172.000000    1174.000000     1008.000000
# mean         199.369676      308.915614     198.085179      697.472222
# std           42.504777      300.923600     127.027890     1228.480511
# ...

# %%
pd.isnull(data['Colesterol LDL']).value_counts()
# Out:
# False    1008
# True      166
# Name: Colesterol LDL, dtype: int64

# %%
data_copia=data

# %%
#Borra las filas en las cuales encuentre todas las columnas vacias
data_copia.dropna(axis=0,how='all')
# Out:
#       Edad (años) Grupo de edad  Genero Regimen de Afiliación Fecha Control  \
# 0              68      65 y mas       2            SUBSIDIADO    28/06/2017
# 1              55       45 a 64       2          CONTRIBUTIVO    25/05/2017
# 2              62       45 a 64       1            SUBSIDIADO    17/05/2017
# 3              69      65 y mas       2            SUBSIDIADO    15/05/2017
# 4              62       45 a 64       2            SUBSIDIADO    12/05/2017
# ...           ...           ...     ...                   ...           ...
# 1169           62       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1170           57       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1171           48       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1172           70      65 y mas       2          CONTRIBUTIVO      AUSENCIA
# 1173           69      65 y mas       1          CONTRIBUTIVO      AUSENCIA
#
# ...

# %%
#Borrar fila que tenga algun dato vacio
data_copia=data_copia.dropna(axis=0,how='any')

# %%
data_copia
# Out:
#       Edad (años) Grupo de edad  Genero Regimen de Afiliación Fecha Control  \
# 0              68      65 y mas       2            SUBSIDIADO    28/06/2017
# 1              55       45 a 64       2          CONTRIBUTIVO    25/05/2017
# 2              62       45 a 64       1            SUBSIDIADO    17/05/2017
# 3              69      65 y mas       2            SUBSIDIADO    15/05/2017
# 4              62       45 a 64       2            SUBSIDIADO    12/05/2017
# ...           ...           ...     ...                   ...           ...
# 1169           62       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1170           57       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1171           48       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1172           70      65 y mas       2          CONTRIBUTIVO      AUSENCIA
# 1173           69      65 y mas       1          CONTRIBUTIVO      AUSENCIA
#
# ...

# %%
pd.isnull(data['Colesterol LDL']).value_counts()
# Out:
# False    1008
# True      166
# Name: Colesterol LDL, dtype: int64

# %%
pd.isnull(data_copia['Colesterol LDL']).value_counts()
# Out:
# False    1000
# Name: Colesterol LDL, dtype: int64

# %%
pd.isnull(data_copia[data_copia.columns[2]]).value_counts()
# Out:
# False    1000
# Name: Genero, dtype: int64

# %%
data_copia
# Out:
#       Edad (años) Grupo de edad  Genero Regimen de Afiliación Fecha Control  \
# 0              68      65 y mas       2            SUBSIDIADO    28/06/2017
# 1              55       45 a 64       2          CONTRIBUTIVO    25/05/2017
# 2              62       45 a 64       1            SUBSIDIADO    17/05/2017
# 3              69      65 y mas       2            SUBSIDIADO    15/05/2017
# 4              62       45 a 64       2            SUBSIDIADO    12/05/2017
# ...           ...           ...     ...                   ...           ...
# 1169           62       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1170           57       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1171           48       45 a 64       2          CONTRIBUTIVO      AUSENCIA
# 1172           70      65 y mas       2          CONTRIBUTIVO      AUSENCIA
# 1173           69      65 y mas       1          CONTRIBUTIVO      AUSENCIA
#
# ...

# %%
data_copia['Colesterol HDL'].mean()
# Out:
# 317.8425

# %%
data['Colesterol HDL'].mean()
# Out:
# 308.91561433447094

# %%
data_copia['Edad (años)'].mean()
# Out:
# 64.254

# %%
data['Edad (años)'].mean()
# Out:
# 64.06984667802385

# %%
data.head()
# Out:
#    Edad (años) Grupo de edad  Genero Regimen de Afiliación Fecha Control  \
# 0           68      65 y mas       2            SUBSIDIADO    28/06/2017
# 1           55       45 a 64       2          CONTRIBUTIVO    25/05/2017
# 2           62       45 a 64       1            SUBSIDIADO    17/05/2017
# 3           69      65 y mas       2            SUBSIDIADO    15/05/2017
# 4           62       45 a 64       2            SUBSIDIADO    12/05/2017
#
#   Fumador Activo ¿Diabetes? Hipertensión Arterial Sistemica HTA + DM  \
# 0             No         Si                              No       No
# 1             No         Si                              Si       Si
# 2             No         Si                              Si       Si
# 3             No         Si                              No       No
# 4             No         Si                              Si       Si
#
#    Tension SISTOLICA  Tension DIASTOLICA HTA COMPENSADOS  Colesterol Total  \
# ...

# %%
pd.isnull(data['Colesterol HDL']).values.ravel().sum()
# Out:
# 2

# %%
for i in range(0,len(data.columns)):
  print(data.columns[i]+': ', pd.isnull(data[data.columns[i]]).values.ravel().sum())
# Out:
# Edad (años):  0
# Grupo de edad:  0
# Genero:  0
# Regimen de Afiliación:  0
# Fecha Control:  0
# Fumador Activo:  0
# ¿Diabetes?:  0
# Hipertensión Arterial Sistemica:  0
# HTA + DM:  0
# Tension SISTOLICA:  0
# Tension DIASTOLICA:  0
# HTA COMPENSADOS:  0
# Colesterol Total:  0
# Colesterol HDL:  2
# Trigliceridos:  0
# Colesterol LDL:  166

# %%
data['Hipertensión Arterial Sistemica'].value_counts()
# Out:
# Si    729
# No    438
# Name: Hipertensión Arterial Sistemica, dtype: int64

# %%
data['Hipertensión Arterial Sistemica'].mode()
# Out:
# 0    Si
# Name: Hipertensión Arterial Sistemica, dtype: object

# %%
#Llenar datos vacios de una columna categórica
data['Hipertensión Arterial Sistemica']=data['Hipertensión Arterial Sistemica'].fillna('Si')
data['Hipertensión Arterial Sistemica']=data['Hipertensión Arterial Sistemica'].fillna(data['Hipertensión Arterial Sistemica'].mode())

# %%
data['Hipertensión Arterial Sistemica'].value_counts(dropna=False)
# Out:
# Si    736
# No    438
# Name: Hipertensión Arterial Sistemica, dtype: int64

# %%
for i in range(0,len(data.columns)):
  print(data.columns[i]+': ', pd.isnull(data[data.columns[i]]).values.ravel().sum())
# Out:
# Edad (años):  0
# Grupo de edad:  0
# Genero:  0
# Regimen de Afiliación:  0
# Fecha Control:  0
# Fumador Activo:  0
# ¿Diabetes?:  0
# Hipertensión Arterial Sistemica:  0
# HTA + DM:  0
# Tension SISTOLICA:  0
# Tension DIASTOLICA:  0
# HTA COMPENSADOS:  0
# Colesterol Total:  0
# Colesterol HDL:  0
# Trigliceridos:  0
# Colesterol LDL:  0

# %%
data['Colesterol HDL'].mean()
# Out:
# 308.91561433447094

# %%
data['Colesterol HDL']=data['Colesterol HDL'].fillna(data['Colesterol HDL'].mean())
data['Colesterol LDL']=data['Colesterol LDL'].fillna(data['Colesterol LDL'].mean())

# %%
data['Colesterol LDL'].mean()
# Out:
# 697.4722222222222

# %%
from  pandas_profiling import ProfileReport

# %%
prof=ProfileReport(data)

# %%
prof
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
uploaded1=files.upload()
# Out:
#      <input type="file" id="files-a9f261cd-5d5f-41a0-8847-87cae539ae1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9f261cd-5d5f-41a0-8847-87cae539ae1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
uploaded2=files.upload()
# Out:
#      <input type="file" id="files-5e743e3f-41ae-4586-9ecf-7d7e568172c1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e743e3f-41ae-4586-9ecf-7d7e568172c1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_r=pd.read_csv(io.BytesIO(uploaded1['red001.csv']))

# %%
data_w=pd.read_csv(io.BytesIO(uploaded2['white001.csv']))

# %%
data_r.shape
# Out:
# (1599, 12)

# %%
data_w.shape
# Out:
# (4898, 12)

# %%
data_r.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data_w.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
data_r['label']=1
data_w['label']=0

# %%
data_w
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      45.00
# 1               6.3              0.30         0.34             1.6      49.00
# 2               8.1              0.28         0.40             6.9       0.05
# 3               7.2              0.23         0.32             8.5      58.00
# 4               7.2              0.23         0.32             8.5      58.00
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      39.00
# 4894            6.6              0.32         0.36             8.0      47.00
# 4895            6.5              0.24         0.19             1.2      41.00
# 4896            5.5              0.29         0.30             1.1      22.00
# 4897            6.0              0.21         0.38             0.8       0.02
#
# ...

# %%
data_concat=pd.concat([data_w, data_r],axis=0)

# %%
data_concat
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      45.00
# 1               6.3              0.30         0.34             1.6      49.00
# 2               8.1              0.28         0.40             6.9       0.05
# 3               7.2              0.23         0.32             8.5      58.00
# 4               7.2              0.23         0.32             8.5      58.00
# ...             ...               ...          ...             ...        ...
# 1594            6.2              0.60         0.08             2.0       0.09
# 1595            5.9              0.55         0.10             2.2      62.00
# 1596            6.3              0.51         0.13             2.3      76.00
# 1597            5.9            645.00         0.12             2.0      75.00
# 1598            6.0              0.31         0.47             3.6      67.00
#
# ...

# %%
data_concat=data_concat.reset_index()

# %%
data_concat
# Out:
#       index  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0         0            7.0              0.27         0.36            20.7
# 1         1            6.3              0.30         0.34             1.6
# 2         2            8.1              0.28         0.40             6.9
# 3         3            7.2              0.23         0.32             8.5
# 4         4            7.2              0.23         0.32             8.5
# ...     ...            ...               ...          ...             ...
# 6492   1594            6.2              0.60         0.08             2.0
# 6493   1595            5.9              0.55         0.10             2.2
# 6494   1596            6.3              0.51         0.13             2.3
# 6495   1597            5.9            645.00         0.12             2.0
# 6496   1598            6.0              0.31         0.47             3.6
#
#       chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# ...

# %%
data_concat=data_concat.drop('index',axis=1)

# %%
data_concat
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      45.00
# 1               6.3              0.30         0.34             1.6      49.00
# 2               8.1              0.28         0.40             6.9       0.05
# 3               7.2              0.23         0.32             8.5      58.00
# 4               7.2              0.23         0.32             8.5      58.00
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.60         0.08             2.0       0.09
# 6493            5.9              0.55         0.10             2.2      62.00
# 6494            6.3              0.51         0.13             2.3      76.00
# 6495            5.9            645.00         0.12             2.0      75.00
# 6496            6.0              0.31         0.47             3.6      67.00
#
# ...

# %%
data_concat[1000:1200]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1000            8.0              0.19         0.36            1.80       0.05
# 1001            6.4              0.28         0.41            6.80      45.00
# 1002            6.4              0.28         0.43            7.10      45.00
# 1003            6.9              0.24         0.39            1.30      63.00
# 1004            5.8              0.36         0.26            3.30      38.00
# ...             ...               ...          ...             ...        ...
# 1195            7.9              0.22         0.45           14.20      38.00
# 1196            6.9              0.25         0.26            5.20      24.00
# 1197            7.3              0.22         0.40           14.75      42.00
# 1198            7.1              0.26         0.32           14.45      74.00
# 1199            7.4              0.25         0.37            6.90       0.02
#
# ...
